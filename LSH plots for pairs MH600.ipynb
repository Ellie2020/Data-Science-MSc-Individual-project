# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot
from matplotlib.pyplot import *
import math

# %%
MH600=pd.read_csv('MH600LSH1LSH3LSH5.csv')

# %%
MH600
# Out:
#     Unnamed: 0   MH  LSH  band    TP_mean    TP_1SE    TN_mean    TN_1SE  \
# 0            0  600    1   300  127469.60  2758.482   80139.40   327.885
# 1            1  600    1   200    2451.00   160.851  265795.00  1666.826
# 2            2  600    1   150      77.80     6.719  414433.60  1347.672
# 3            3  600    1   100       2.20     0.200  490812.20   277.088
# 4            4  600    1    50       2.00     0.000  499407.60     1.720
# 5            5  600    1    30       2.00     0.000  499493.50     0.645
# 6            6  600    3   300  410194.00  1614.392   59155.80  1877.955
# 7            7  600    3   200  213350.80   992.707  206171.80  3163.943
# 8            8  600    3   150    6250.20   360.166  414661.40   634.486
# 9            9  600    3   100     352.75    33.510  491383.50   308.381
# 10          10  600    3    50       2.00     0.000  499407.50     3.175
# 11          11  600    3    30       2.00     0.000  499493.83     0.401
# 12           0  600    5   300  409038.00  1143.087   61052.00   828.409
# 13           0  600    5   200  210291.00  1122.959  216704.57   594.848
# 14           0  600    5   150   58426.50  1299.055  384587.25  1911.390
# 15           0  600    5   100     563.60    31.101  490894.80   345.241
# 16           0  600    5    50       2.25     0.250  499406.50     2.901
# 17           0  600    5    30       2.17     0.167  499494.17     0.601
#
#      FP_mean    FP_1SE  ...    FN_1SE  Accuracy_mean  Acc_1SE  Precision_mean  \
# 0      18.40     8.687  ...  2866.687           0.42    0.006            1.00
# 1       0.20     0.200  ...  1587.064           0.54    0.003            1.00
# 2       0.00     0.000  ...  1350.253           0.83    0.003            1.00
# 3       0.00     0.000  ...   277.080           0.98    0.001            1.00
# 4       0.00     0.000  ...     1.720           1.00    0.000            1.00
# 5       0.00     0.000  ...     0.645           1.00    0.000            1.00
# 6   20037.60  1740.122  ...  1451.379           0.94    0.001            0.95
# 7   62670.40  3906.789  ...   886.796           0.84    0.006            0.77
# 8     131.40    22.787  ...   539.885           0.84    0.001            0.98
# 9      23.25     7.341  ...   273.324           0.98    0.001            0.94
# 10      0.00     0.000  ...     3.175           1.00    0.000            1.00
# 11      0.00     0.000  ...     0.401           1.00    0.000            1.00
# 12  18521.00   781.600  ...   824.930           0.94    0.001            0.96
# 13  51404.00  1152.937  ...   733.962           0.85    0.001            0.80
# 14  28608.75  1506.528  ...   885.774           0.89    0.001            0.67
# 15     46.60     4.792  ...   319.984           0.98    0.001            0.92
# 16      0.00     0.000  ...     3.065           1.00    0.000            1.00
# 17      0.00     0.000  ...     0.667           1.00    0.000            1.00
#
#     Prec_1SE  Recall_mean  Recall_1SE   F1_mean    F1_1SE  SIM_t
# 0      0.000     0.300000    0.007000  0.470000  0.008000  0.058
# 1      0.000     0.010479    0.000654  0.020738  0.001280  0.171
# 2      0.000     0.000917    0.000085  0.001833  0.000170  0.286
# 3      0.000     0.000254    0.000023  0.000508  0.000047  0.464
# 4      0.000     0.021675    0.000405  0.042429  0.000775  0.722
# 5      0.000     0.320000    0.032000  0.480000  0.037000  0.844
# 6      0.004     0.980000    0.003000  0.960000  0.001000  0.058
# 7      0.011     0.930000    0.004000  0.840000  0.005000  0.171
# 8      0.002     0.070000    0.004000  0.140000  0.007000  0.286
# 9      0.016     0.040000    0.003000  0.080000  0.005000  0.464
# 10     0.000     0.020000    0.001000  0.040000  0.002000  0.722
# 11     0.000     0.330000    0.023000  0.500000  0.025000  0.844
# 12     0.002     0.970000    0.002000  0.970000  0.001000  0.058
# 13     0.004     0.910000    0.003000  0.850000  0.002000  0.171
# 14     0.007     0.680000    0.012000  0.670000  0.003000  0.286
# 15     0.005     0.070000    0.002000  0.120000  0.004000  0.464
# 16     0.000     0.020000    0.003000  0.050000  0.006000  0.722
# 17     0.000     0.390000    0.055000  0.560000  0.055000  0.844
#
# [18 rows x 21 columns]

# %%
MH600.columns
# Out:
# Index(['Unnamed: 0', 'MH', 'LSH', 'band', 'TP_mean', 'TP_1SE', 'TN_mean',
#        'TN_1SE', 'FP_mean', 'FP_1SE', 'FN_mean', 'FN_1SE', 'Accuracy_mean',
#        'Acc_1SE', 'Precision_mean', 'Prec_1SE', 'Recall_mean', 'Recall_1SE',
#        'F1_mean', 'F1_1SE', 'SIM_t'],
#       dtype='object')

# %%
MH600.band.unique()
# Out:
# array([300, 200, 150, 100,  50,  30], dtype=int64)

# %% [markdown]
# ## MH600 B300

# %%
MH600B300=MH600[MH600['band'].eq(300)]
MH600B300.drop(MH600B300.filter(regex="Unname"),axis=1, inplace=True)
MH600B300
# Out:
# C:\Users\Ellie\Anaconda3\envs\songs\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      MH  LSH  band   TP_mean    TP_1SE  TN_mean    TN_1SE  FP_mean    FP_1SE  \
# 0   600    1   300  127469.6  2758.482  80139.4   327.885     18.4     8.687
# 6   600    3   300  410194.0  1614.392  59155.8  1877.955  20037.6  1740.122
# 12  600    5   300  409038.0  1143.087  61052.0   828.409  18521.0   781.600
#
#      FN_mean    FN_1SE  Accuracy_mean  Acc_1SE  Precision_mean  Prec_1SE  \
# 0   291872.6  2866.687           0.42    0.006            1.00     0.000
# 6    10112.6  1451.379           0.94    0.001            0.95     0.004
# 12   10889.0   824.930           0.94    0.001            0.96     0.002
#
#     Recall_mean  Recall_1SE  F1_mean  F1_1SE  SIM_t
# 0          0.30       0.007     0.47   0.008  0.058
# 6          0.98       0.003     0.96   0.001  0.058
# 12         0.97       0.002     0.97   0.001  0.058

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D
a=MH600B300
fig, ax = plt.subplots(figsize=(8,5))

# get handles
handles, labels = ax.get_legend_handles_labels()

x=['1','3','5']

trans1 = Affine2D().translate(-0.005, 0.0) + ax.transData
trans2 = Affine2D().translate(+0.005, 0.0) + ax.transData

y= [a.Recall_mean.values[0], a.Recall_mean.values[1], a.Recall_mean.values[2]]
e = [a.Recall_1SE.values[0], a.Recall_1SE.values[1],a.Recall_1SE.values[2]]

y2 = [a.Precision_mean.values[0], a.Precision_mean.values[1], a.Precision_mean.values[2]]
e2 = [a.Prec_1SE.values[0],a.Prec_1SE.values[1],a.Prec_1SE.values[2]]

er = ax.errorbar(x, y, yerr=e, marker="o", linestyle='dotted', transform=trans1, label='Recall')

ax2 = ax.twinx()  

er2 = ax2.errorbar(x, y2, yerr=e2, marker="o", linestyle="dotted", color='r', label='Precision')

ax.set_ylabel('Recall',fontsize=16)
ax2.set_ylabel('Precision',fontsize=16)
ax.set_xlabel('LSH',fontsize=14)
ax.legend(bbox_to_anchor=(1.5, 0.9), fontsize=14)
ax2.legend(bbox_to_anchor=(1.5, 1.05), fontsize=14)
ax.tick_params(labelcolor='black', labelsize=14, width=3)
plt.show()

# %%
#MH600 bands 300

MH600B300=MH600[MH600['band'].eq(300)]
MH600B300
x=['1','3','5']
df1=MH600B300[['LSH','TP_mean', 'TP_1SE', 'TN_mean', 'TN_1SE', 'FP_mean', 'FP_1SE', 'FN_mean', 'FN_1SE']]
df1=df1.set_index('LSH')
matplotlib.rcParams.update({'font.size': 14})
df1[['TP_mean', 'TN_mean','FP_mean', 'FN_mean']].plot(kind='bar', yerr=df1[['TP_1SE', 'TN_1SE','FP_1SE','FN_1SE']].values.T , rot=0, alpha = 1,error_kw=dict(ecolor='k'), figsize=(8,5))
plt.legend(loc=(1.04,0.8))
plt.xticks(fontsize=16)

plt.show()

# %%
MH600.band.unique()
# Out:
# array([300, 200, 150, 100,  50,  30], dtype=int64)

# %% [markdown]
# ## MH600 B200

# %%
MH600B200=MH600[MH600['band'].eq(200)]
MH600B200.drop(MH600B300.filter(regex="Unname"),axis=1, inplace=True)
MH600B200
# Out:
#      MH  LSH  band   TP_mean    TP_1SE    TN_mean    TN_1SE  FP_mean  \
# 1   600    1   200    2451.0   160.851  265795.00  1666.826      0.2
# 7   600    3   200  213350.8   992.707  206171.80  3163.943  62670.4
# 13  600    5   200  210291.0  1122.959  216704.57   594.848  51404.0
#
#       FP_1SE    FN_mean    FN_1SE  Accuracy_mean  Acc_1SE  Precision_mean  \
# 1      0.200  231253.80  1587.064           0.54    0.003            1.00
# 7   3906.789   17307.00   886.796           0.84    0.006            0.77
# 13  1152.937   21100.43   733.962           0.85    0.001            0.80
#
#     Prec_1SE  Recall_mean  Recall_1SE   F1_mean   F1_1SE  SIM_t
# 1      0.000     0.010479    0.000654  0.020738  0.00128  0.171
# 7      0.011     0.930000    0.004000  0.840000  0.00500  0.171
# 13     0.004     0.910000    0.003000  0.850000  0.00200  0.171

# %%
MH600B200=MH600[MH600['band'].eq(200)]
MH600B200.drop(MH600B300.filter(regex="Unname"),axis=1, inplace=True)
MH600B200

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D
a=MH600B200
fig, ax = plt.subplots(figsize=(8,5))

# get handles
handles, labels = ax.get_legend_handles_labels()

x=['1','3','5']

trans1 = Affine2D().translate(-0.005, 0.0) + ax.transData
trans2 = Affine2D().translate(+0.005, 0.0) + ax.transData

y= [a.Recall_mean.values[0], a.Recall_mean.values[1], a.Recall_mean.values[2]]
e = [a.Recall_1SE.values[0], a.Recall_1SE.values[1],a.Recall_1SE.values[2]]

y2 = [a.Precision_mean.values[0], a.Precision_mean.values[1], a.Precision_mean.values[2]]
e2 = [a.Prec_1SE.values[0],a.Prec_1SE.values[1],a.Prec_1SE.values[2]]

er = ax.errorbar(x, y, yerr=e, marker="o", linestyle='dotted', transform=trans1, label='Recall')

ax2 = ax.twinx()  

er2 = ax2.errorbar(x, y2, yerr=e2, marker="o", linestyle="dotted", color='r', label='Precision')

ax.set_ylabel('Recall',fontsize=16)
ax2.set_ylabel('Precision',fontsize=16)
ax.set_xlabel('LSH',fontsize=14)
ax.legend(bbox_to_anchor=(1.5, 0.9), fontsize=14)
ax2.legend(bbox_to_anchor=(1.5, 1.05), fontsize=14)
ax.tick_params(labelcolor='black', labelsize=14, width=3)
plt.show()

# %%
#MH600 bands 200
MH600B200=MH600[MH600['band'].eq(200)]

x=['1','3','5']
df1=MH600B200[['LSH','TP_mean', 'TP_1SE', 'TN_mean', 'TN_1SE', 'FP_mean', 'FP_1SE', 'FN_mean', 'FN_1SE']]
df1=df1.set_index('LSH')
matplotlib.rcParams.update({'font.size': 14})
df1[['TP_mean', 'TN_mean','FP_mean', 'FN_mean']].plot(kind='bar', yerr=df1[['TP_1SE', 'TN_1SE','FP_1SE','FN_1SE']].values.T , rot=0, alpha = 1,error_kw=dict(ecolor='k'), figsize=(8,5))
plt.legend(loc=(1.04,0.8))
plt.xticks(fontsize=16)

plt.show()

# %%
MH600.band.unique()
# Out:
# array([300, 200, 150, 100,  50,  30], dtype=int64)

# %% [markdown]
# ## MH600 B150

# %%
MH600B150=MH600[MH600['band'].eq(150)]
MH600B150.drop(MH600B150.filter(regex="Unname"),axis=1, inplace=True)
MH600B150
# Out:
#      MH  LSH  band  TP_mean    TP_1SE    TN_mean    TN_1SE   FP_mean  \
# 2   600    1   150     77.8     6.719  414433.60  1347.672      0.00
# 8   600    3   150   6250.2   360.166  414661.40   634.486    131.40
# 14  600    5   150  58426.5  1299.055  384587.25  1911.390  28608.75
#
#       FP_1SE  FN_mean    FN_1SE  Accuracy_mean  Acc_1SE  Precision_mean  \
# 2      0.000  84988.6  1350.253           0.83    0.003            1.00
# 8     22.787  78457.0   539.885           0.84    0.001            0.98
# 14  1506.528  27877.5   885.774           0.89    0.001            0.67
#
#     Prec_1SE  Recall_mean  Recall_1SE   F1_mean   F1_1SE  SIM_t
# 2      0.000     0.000917    0.000085  0.001833  0.00017  0.286
# 8      0.002     0.070000    0.004000  0.140000  0.00700  0.286
# 14     0.007     0.680000    0.012000  0.670000  0.00300  0.286

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D
a=MH600B150
fig, ax = plt.subplots(figsize=(8,5))

# get handles
handles, labels = ax.get_legend_handles_labels()

x=['1','3','5']

trans1 = Affine2D().translate(-0.005, 0.0) + ax.transData
trans2 = Affine2D().translate(+0.005, 0.0) + ax.transData

y= [a.Recall_mean.values[0], a.Recall_mean.values[1], a.Recall_mean.values[2]]
e = [a.Recall_1SE.values[0], a.Recall_1SE.values[1],a.Recall_1SE.values[2]]

y2 = [a.Precision_mean.values[0], a.Precision_mean.values[1], a.Precision_mean.values[2]]
e2 = [a.Prec_1SE.values[0],a.Prec_1SE.values[1],a.Prec_1SE.values[2]]

er = ax.errorbar(x, y, yerr=e, marker="o", linestyle='dotted', transform=trans1, label='Recall')

ax2 = ax.twinx()  

er2 = ax2.errorbar(x, y2, yerr=e2, marker="o", linestyle="dotted", color='r', label='Precision')

ax.set_ylabel('Recall',fontsize=16)
ax2.set_ylabel('Precision',fontsize=16)
ax.set_xlabel('LSH',fontsize=14)
ax.legend(bbox_to_anchor=(1.5, 0.9), fontsize=14)
ax2.legend(bbox_to_anchor=(1.5, 1.05), fontsize=14)
ax.tick_params(labelcolor='black', labelsize=14, width=3)
plt.show()

# %%
#MH600 band150
MH600B150
x=['1','3','5']
df1=MH600B150[['LSH','TP_mean', 'TP_1SE', 'TN_mean', 'TN_1SE', 'FP_mean', 'FP_1SE', 'FN_mean', 'FN_1SE']]
df1=df1.set_index('LSH')
matplotlib.rcParams.update({'font.size': 14})
df1[['TP_mean', 'TN_mean','FP_mean', 'FN_mean']].plot(kind='bar', yerr=df1[['TP_1SE', 'TN_1SE','FP_1SE','FN_1SE']].values.T , rot=0, alpha = 1,error_kw=dict(ecolor='k'), figsize=(8,5))
plt.legend(loc=(1.04,0.8))
plt.xticks(fontsize=16)

plt.show()

# %% [markdown]
# ## MH600 B100

# %%
MH600B100=MH600[MH600['band'].eq(100)]
MH600B100
# Out:
#     Unnamed: 0   MH  LSH  band  TP_mean  TP_1SE   TN_mean   TN_1SE  FP_mean  \
# 3            3  600    1   100     2.20   0.200  490812.2  277.088     0.00
# 9            9  600    3   100   352.75  33.510  491383.5  308.381    23.25
# 15           0  600    5   100   563.60  31.101  490894.8  345.241    46.60
#
#     FP_1SE  ...   FN_1SE  Accuracy_mean  Acc_1SE  Precision_mean  Prec_1SE  \
# 3    0.000  ...  277.080           0.98    0.001            1.00     0.000
# 9    7.341  ...  273.324           0.98    0.001            0.94     0.016
# 15   4.792  ...  319.984           0.98    0.001            0.92     0.005
#
#     Recall_mean  Recall_1SE   F1_mean    F1_1SE  SIM_t
# 3      0.000254    0.000023  0.000508  0.000047  0.464
# 9      0.040000    0.003000  0.080000  0.005000  0.464
# 15     0.070000    0.002000  0.120000  0.004000  0.464
#
# [3 rows x 21 columns]

# %%
MH600B100=MH600[MH600['band'].eq(100)]
MH600B100.drop(MH600B100.filter(regex="Unname"),axis=1, inplace=True)
MH600B100

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D
a=MH600B100
fig, ax = plt.subplots(figsize=(8,5))

# get handles
handles, labels = ax.get_legend_handles_labels()

x=['1','3','5']

trans1 = Affine2D().translate(-0.005, 0.0) + ax.transData
trans2 = Affine2D().translate(+0.005, 0.0) + ax.transData

y= [a.Recall_mean.values[0], a.Recall_mean.values[1], a.Recall_mean.values[2]]
e = [a.Recall_1SE.values[0], a.Recall_1SE.values[1],a.Recall_1SE.values[2]]

y2 = [a.Precision_mean.values[0], a.Precision_mean.values[1], a.Precision_mean.values[2]]
e2 = [a.Prec_1SE.values[0],a.Prec_1SE.values[1],a.Prec_1SE.values[2]]

er = ax.errorbar(x, y, yerr=e, marker="o", linestyle='dotted', transform=trans1, label='Recall')

ax2 = ax.twinx()  

er2 = ax2.errorbar(x, y2, yerr=e2, marker="o", linestyle="dotted", color='r', label='Precision')

ax.set_ylabel('Recall',fontsize=16)
ax2.set_ylabel('Precision',fontsize=16)
ax.set_xlabel('LSH',fontsize=14)
ax.legend(bbox_to_anchor=(1.5, 0.9), fontsize=14)
ax2.legend(bbox_to_anchor=(1.5, 1.05), fontsize=14)
ax.tick_params(labelcolor='black', labelsize=14, width=3)
plt.show()

# %%
#MH600 band100
MH600B100=MH600[MH600['band'].eq(100)]
MH600B100.drop(MH600B100.filter(regex="Unname"),axis=1, inplace=True)
MH600B100
x=['1','3','5']
df1=MH600B100[['LSH','TP_mean', 'TP_1SE', 'TN_mean', 'TN_1SE', 'FP_mean', 'FP_1SE', 'FN_mean', 'FN_1SE']]
df1=df1.set_index('LSH')
matplotlib.rcParams.update({'font.size': 14})
df1[['TP_mean', 'TN_mean','FP_mean', 'FN_mean']].plot(kind='bar', yerr=df1[['TP_1SE', 'TN_1SE','FP_1SE','FN_1SE']].values.T , rot=0, alpha = 1,error_kw=dict(ecolor='k'), figsize=(8,5))
plt.legend(loc=(1.04,0.8))
plt.xticks(fontsize=16)

plt.show()

# %% [markdown]
# ## MH600 B50

# %%
MH600.band.unique()
# Out:
# array([300, 200, 150, 100,  50,  30], dtype=int64)

# %%
MH600B50=MH600[MH600['band'].eq(50)]
MH600B50.drop(MH600B50.filter(regex="Unname"),axis=1, inplace=True)
MH600B50
# Out:
#      MH  LSH  band  TP_mean  TP_1SE   TN_mean  TN_1SE  FP_mean  FP_1SE  \
# 4   600    1    50     2.00    0.00  499407.6   1.720      0.0     0.0
# 10  600    3    50     2.00    0.00  499407.5   3.175      0.0     0.0
# 16  600    5    50     2.25    0.25  499406.5   2.901      0.0     0.0
#
#     FN_mean  FN_1SE  Accuracy_mean  Acc_1SE  Precision_mean  Prec_1SE  \
# 4     90.40   1.720            1.0      0.0             1.0       0.0
# 10    90.50   3.175            1.0      0.0             1.0       0.0
# 16    91.25   3.065            1.0      0.0             1.0       0.0
#
#     Recall_mean  Recall_1SE   F1_mean    F1_1SE  SIM_t
# 4      0.021675    0.000405  0.042429  0.000775  0.722
# 10     0.020000    0.001000  0.040000  0.002000  0.722
# 16     0.020000    0.003000  0.050000  0.006000  0.722

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D
a=MH600B50
fig, ax = plt.subplots(figsize=(8,5))

# get handles
handles, labels = ax.get_legend_handles_labels()

x=['1','3','5']

trans1 = Affine2D().translate(-0.005, 0.0) + ax.transData
trans2 = Affine2D().translate(+0.005, 0.0) + ax.transData

y= [a.Recall_mean.values[0], a.Recall_mean.values[1], a.Recall_mean.values[2]]
e = [a.Recall_1SE.values[0], a.Recall_1SE.values[1],a.Recall_1SE.values[2]]

y2 = [a.Precision_mean.values[0], a.Precision_mean.values[1], a.Precision_mean.values[2]]
e2 = [a.Prec_1SE.values[0],a.Prec_1SE.values[1],a.Prec_1SE.values[2]]

er = ax.errorbar(x, y, yerr=e, marker="o", linestyle='dotted', transform=trans1, label='Recall')

ax2 = ax.twinx()  

er2 = ax2.errorbar(x, y2, yerr=e2, marker="o", linestyle="dotted", color='r', label='Precision')

ax.set_ylabel('Recall',fontsize=16)
ax2.set_ylabel('Precision',fontsize=16)
ax.set_xlabel('LSH',fontsize=14)
ax.legend(bbox_to_anchor=(1.5, 0.9), fontsize=14)
ax2.legend(bbox_to_anchor=(1.5, 1.05), fontsize=14)
ax.tick_params(labelcolor='black', labelsize=14, width=3)
plt.show()

# %%
#MH600 band 50
MH600B50
x=['1','3','5']
df1=MH600B50[['LSH','TP_mean', 'TP_1SE', 'TN_mean', 'TN_1SE', 'FP_mean', 'FP_1SE', 'FN_mean', 'FN_1SE']]
df1=df1.set_index('LSH')
matplotlib.rcParams.update({'font.size': 14})
df1[['TP_mean', 'TN_mean','FP_mean', 'FN_mean']].plot(kind='bar', yerr=df1[['TP_1SE', 'TN_1SE','FP_1SE','FN_1SE']].values.T , rot=0, alpha = 1,error_kw=dict(ecolor='k'), figsize=(8,5))
plt.legend(loc=(1.04,0.8))
plt.xticks(fontsize=16)

plt.show()

# %% [markdown]
# ## MH600 B30

# %%
MH600B30=MH600[MH600['band'].eq(30)]
MH600B30.drop(MH600B30.filter(regex="Unname"),axis=1, inplace=True)
MH600B30
# Out:
#      MH  LSH  band  TP_mean  TP_1SE    TN_mean  TN_1SE  FP_mean  FP_1SE  \
# 5   600    1    30     2.00   0.000  499493.50   0.645      0.0     0.0
# 11  600    3    30     2.00   0.000  499493.83   0.401      0.0     0.0
# 17  600    5    30     2.17   0.167  499494.17   0.601      0.0     0.0
#
#     FN_mean  FN_1SE  Accuracy_mean  Acc_1SE  Precision_mean  Prec_1SE  \
# 5      4.50   0.645            1.0      0.0             1.0       0.0
# 11     4.17   0.401            1.0      0.0             1.0       0.0
# 17     3.67   0.667            1.0      0.0             1.0       0.0
#
#     Recall_mean  Recall_1SE  F1_mean  F1_1SE  SIM_t
# 5          0.32       0.032     0.48   0.037  0.844
# 11         0.33       0.023     0.50   0.025  0.844
# 17         0.39       0.055     0.56   0.055  0.844

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.transforms import Affine2D
a=MH600B30
fig, ax = plt.subplots(figsize=(8,5))

# get handles
handles, labels = ax.get_legend_handles_labels()

x=['1','3','5']

trans1 = Affine2D().translate(-0.005, 0.0) + ax.transData
trans2 = Affine2D().translate(+0.005, 0.0) + ax.transData

y= [a.Recall_mean.values[0], a.Recall_mean.values[1], a.Recall_mean.values[2]]
e = [a.Recall_1SE.values[0], a.Recall_1SE.values[1],a.Recall_1SE.values[2]]

y2 = [a.Precision_mean.values[0], a.Precision_mean.values[1], a.Precision_mean.values[2]]
e2 = [a.Prec_1SE.values[0],a.Prec_1SE.values[1],a.Prec_1SE.values[2]]

er = ax.errorbar(x, y, yerr=e, marker="o", linestyle='dotted', transform=trans1, label='Recall')

ax2 = ax.twinx()  

er2 = ax2.errorbar(x, y2, yerr=e2, marker="o", linestyle="dotted", color='r', label='Precision')

ax.set_ylabel('Recall',fontsize=16)
ax2.set_ylabel('Precision',fontsize=16)
ax.set_xlabel('LSH',fontsize=14)
ax.legend(bbox_to_anchor=(1.5, 0.9), fontsize=14)
ax2.legend(bbox_to_anchor=(1.5, 1.05), fontsize=14)
ax.tick_params(labelcolor='black', labelsize=14, width=3)
plt.show()

# %%
#MH600 band 50
MH600B30
x=['1','3','5']
df1=MH600B30[['LSH','TP_mean', 'TP_1SE', 'TN_mean', 'TN_1SE', 'FP_mean', 'FP_1SE', 'FN_mean', 'FN_1SE']]
df1=df1.set_index('LSH')
matplotlib.rcParams.update({'font.size': 14})
df1[['TP_mean', 'TN_mean','FP_mean', 'FN_mean']].plot(kind='bar', yerr=df1[['TP_1SE', 'TN_1SE','FP_1SE','FN_1SE']].values.T , rot=0, alpha = 1,error_kw=dict(ecolor='k'), figsize=(8,5))
plt.legend(loc=(1.04,0.8))
plt.xticks(fontsize=16)

plt.show()
